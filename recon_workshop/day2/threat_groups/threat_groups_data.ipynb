# %% [markdown]
# # Threat Groups

# %% [markdown]
# # Working with data
#
# ## Task 1
#
# APT Threat Groups breakdown - JSON

# %%
import json

json_data = '{"a": 1, "b": 2, "c": 3, "d": 4, "e": 5}'

# json.loads for string
loaded_json = json.loads(json_data)
for x in loaded_json:
    print("%s: %d" % (x, loaded_json[x]))
    
test_json = {
    "name":"changed",
    "date":"a date"
}

print("Test json: ", test_json)
    
with open('test_json_data.json', 'w') as outfile:
    json.dump(test_json, outfile)
    
# with open('json_data.json', 'w') as outfile:
#     json.dump(research, outfile)
# Out:
# a: 1
# b: 2
# c: 3
# d: 4
# e: 5
# Test json:  {'name': 'changed', 'date': 'a date'}

# %% [markdown]
# Serialisation and deserialisation

# %%
import json

# load .. with
with open('threat_group_card.json', 'r') as file:
    apt_file = json.load(file)

# print(apt_file['values'][0])

# for value in apt_file['values']:
#     print("Value: ", value['actor'])

print(apt_file.values().)

for value in apt_file['values']:
    # if 'observed-countries' not in value:
    #     print("Attribute doesn't exist for: ", value)
    if 'observed-countries' in value and "Australia" in value['observed-countries']:
        # if "Australia" in value['observed-countries']:
        print("Attribute exists for: ", value, '\n\n')
        # if country == "Australia":
        # print("Value: ", value)


# print(list(filter(lambda x:x["observed-countries"]=="Australia",apt_file)))

# %%
import pandas as pd
import json

# load data using Python JSON module
with open('threat_group_card.json','r') as file:
    data = json.load(file)
    
# Flatten data
df_nested_list = pd.json_normalize(data, record_path=['values'])
df_nested_list
# Out:
#                 actor                                              names
# 0           Big Panda  [{'name': 'Big Panda', 'name-giver': 'CrowdStr...  \
# 1        Boulder Bear  [{'name': 'Boulder Bear', 'name-giver': 'Crowd...
# 2    Clockwork Spider  [{'name': 'Clockwork Spider', 'name-giver': 'C...
# 3      Corsair Jackal  [{'name': 'Corsair Jackal', 'name-giver': 'Cro...
# 4    Dextorous Spider  [{'name': 'Dextorous Spider', 'name-giver': 'C...
# ..                ...                                                ...
# 424           UNC1878     [{'name': 'UNC1878', 'name-giver': 'FireEye'}]
# 425       [Vault 7/8]       [{'name': '[Vault 7/8]', 'name-giver': '?'}]
# 426      Yanbian Gang      [{'name': 'Yanbian Gang', 'name-giver': '?'}]
# 427           Yingmob   [{'name': 'Yingmob', 'name-giver': 'real name'}]
# 428     Zombie Spider  [{'name': 'Zombie Spider', 'name-giver': 'Crow...
#
#          country                                        description
# ...

# %%
import requests
from IPython.display import Image
from IPython.core.display import HTML 


website = "https://google.com"

response = requests.get(website)
print("Status code: ", response.status_code)

'https://httpcats.com/200.jpg'
Image(url="https://httpcats.com/"+str(response.status_code)+".jpg")

# addition = response.status_code + 200
# print("Addition: ", addition)

# %%
import requests
from IPython.display import Image
from IPython.core.display import HTML 


response = requests.get("https://www.google.com")
print(response)
print("Status code: ", response.status_code)
# print(response.url)

# debugging
print(type(str(response.status_code)))

# Image(url= "https://httpcats.com/"+response.status_code+".jpg", width=400)
# Out:
# <Response [200]>
# Status code:  200
# <class 'str'>

# %% [markdown]
# # Subdomains
#
# ## Assets

# %%
import json

json_data = '{"a": 1, "b": 2, "c": 3, "d": 4, "e": 5}'

# for item in json_data:

intelligence_db = '{"1": "cupcake warriors","2": "http cats"}'

# # json.loads for string
# loaded_json = json.loads(json_data)
# for x in loaded_json:
#     print("%s: %d" % (x, loaded_json[x]))
    

intel_db_json = json.loads(intelligence_db)
for item in intel_db_json:
    print(intel_db_json[item])

# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x106ed03c0>
