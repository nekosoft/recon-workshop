# %% [markdown]
# # Company Profiling
#
# ## What:
# - understand a company and how it's structured
# - map initial attack surface, including investments
# - identify what the company finds important
# - find information to further dig into
#
# ## Why:
# - better understand what a company wants to protect
# - how a phishing campaign might be crafted against the company
# - the potential of insider threat
# - technical vulnerabilities
# - brand impersonation
#
# Can you think of other reasons why?
#
# ## How:
#
# - using Open Source Intelligence
# - passive and active reconnaissance

# %% [markdown]
# ### Registering accounts on sites
#
# - what is the process like?
# - password reset - how do they do this? (bring up oreilly and shodan examples)

# %% [markdown]
# Break down each thing and provide some resources to find the information

# %% [markdown]
# ### Company Overview: Example Approach
#
# ![company_overview.png](attachment:2a7381bb-5e9b-42cb-be00-2905caf0aa7f.png)
